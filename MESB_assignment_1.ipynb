# %%
import matplotlib.pyplot as plt
#Si = 100
Vmax = 10
Km = 5
x = []
y = []
T = []
T.append(0)
t=1
g=open("MESB_Asgn1.csv",'w')
g.write(f"Time(s), Velocity\n")
for Si in range(0,100,1):
    Vi = (Vmax*Si)/(Km+Si) 
    print(Vi)
    if Vi==0:
        pass
    else:    
        t= t*Si/Vi
    y.append(Vi)  
    x.append(Si)
    T.append(t)
    g.write(f"{t}, {Vi}\n")
#if Vi == Vmax:
     #   print(Vi)
      #  break
plt.plot(x,y)
# Out:
# 0.0
# 1.6666666666666667
# 2.857142857142857
# 3.75
# 4.444444444444445
# 5.0
# 5.454545454545454
# 5.833333333333333
# 6.153846153846154
# 6.428571428571429
# 6.666666666666667
# 6.875
# 7.0588235294117645
# 7.222222222222222
# 7.368421052631579
# 7.5
# 7.619047619047619
# 7.7272727272727275
# 7.826086956521739
# 7.916666666666667
# 8.0
# 8.076923076923077
# 8.148148148148149
# 8.214285714285714
# 8.275862068965518
# 8.333333333333334
# 8.387096774193548
# 8.4375
# 8.484848484848484
# 8.529411764705882
# 8.571428571428571
# 8.61111111111111
# 8.64864864864865
# 8.68421052631579
# 8.717948717948717
# 8.75
# 8.78048780487805
# 8.80952380952381
# 8.837209302325581
# 8.863636363636363
# 8.88888888888889
# 8.91304347826087
# 8.936170212765957
# 8.958333333333334
# 8.979591836734693
# 9.0
# 9.019607843137255
# 9.038461538461538
# 9.056603773584905
# 9.074074074074074
# 9.090909090909092
# 9.107142857142858
# 9.12280701754386
# 9.137931034482758
# 9.152542372881356
# 9.166666666666666
# ...

# %%
# Out:
# [0,
#  1,
#  1.5,
#  3.75,
#  13.125,
#  59.0625,
#  324.84374999999994,
#  2111.484375,
#  15836.132812499998,
#  134607.12890624997,
#  1278767.724609375]
